# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader,Dataset
import pandas as pd
import numpy as np
import torch.nn.functional as F
import torch.optim as optim

# %%
import kagglehub


# Download latest version
path = kagglehub.dataset_download("kritanjalijain/amazon-reviews")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/amazon-reviews

# %%
import os
print(os.listdir(path))
# Out:
# ['amazon_review_polarity_csv.tgz', 'train.csv', 'test.csv']

# %%
print("Dataset Loading")
try:
  train = pd.read_csv(path+'/train.csv')[:80000]
  test = pd.read_csv(path+'/test.csv')[:20000]
  print("Dataset Loaded")
except FileNotFoundError:
  print("Dataset not found")
# Out:
# Dataset Loading
# Dataset Loaded

# %%
column_names=['polarity','title','text']
train.columns=column_names

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
train.shape
# Out:
# (80000, 3)

# %% [markdown]
# # Removing Punctions from data

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
train[train['title'].isnull()]
# Out:
#        polarity title                                               text
# 13264         1   NaN  Couldn't get the device to work with my networ...
# 26553         1   NaN  What separates this band from Evanescence (bes...
# 26826         2   NaN  Falkenbach returns with more of the Viking/Fol...
# 36597         2   NaN  I returned this because I received the same on...
# 37346         2   NaN  This book is a great fantasy. I love this amaz...

# %%
train.drop(train[train['title'].isnull()].index, inplace = True)

# %%
import re
def remove_punctuations(text):
  if not isinstance(text, str):
    text = str(text).lower()
  return re.sub(r'[^\w\s]', '', text.lower())
vectorized_func = np.vectorize(remove_punctuations)

# %% [markdown]
# # Analysing The Trend of most used words

# %%
train['title'] = train['title'].apply(vectorized_func)

# %%
train['title']
# Out:
# 0                     the best soundtrack ever to anything
# 1                                                  amazing
# 2                                     excellent soundtrack
# 3        remember pull your jaw off the floor after hea...
# 4                                  an absolute masterpiece
#                                ...
# 79995                   not nearly as good the second time
# 79996                     someone has to die  dramamystery
# 79997                   plenty of graphic sex and violence
# 79998                                            pointless
# 79999              revisionist revenge chick flick rubbish
# Name: title, Length: 79995, dtype: object

# %%
train['text'] = train['text'].apply(vectorized_func)

# %%
x_train= train.iloc[:,2].to_numpy()
y_train = train.iloc[:,0].to_numpy()

x_test = test.iloc[:, 2].to_numpy()
y_test = test.iloc[:, 0].to_numpy()

# %%
x_train.shape
# Out:
# (79995,)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

# %%
train['title'].iloc[2]
# Out:
# 'excellent soundtrack'

# %%
train
# Out:
#        polarity                                              title  \
# 0             2               the best soundtrack ever to anything
# 1             2                                            amazing
# 2             2                               excellent soundtrack
# 3             2  remember pull your jaw off the floor after hea...
# 4             2                            an absolute masterpiece
# ...         ...                                                ...
# 79995         1                 not nearly as good the second time
# 79996         2                   someone has to die  dramamystery
# 79997         2                 plenty of graphic sex and violence
# 79998         1                                          pointless
# 79999         1            revisionist revenge chick flick rubbish
#
#                                                     text
# 0      im reading a lot of reviews saying that this i...
# 1      this soundtrack is my favorite music of all ti...
# 2      i truly like this soundtrack and i enjoy video...
# 3      if youve played the game you know how divine t...
# 4      i am quite sure any of you actually taking the...
# ...                                                  ...
# 79995  sharon stone displays the extent of her er tal...
# 79996  basic instinct is a story of a killing that le...
# 79997  basic instinct verhoeven has crafted a sleazy ...
# 79998  why release this on dvd without the extra foot...
# 79999  on first viewing its check out the architectur...
#
# [79995 rows x 3 columns]

# %% [markdown]
# # **AS WE KNOW THAT WORD2VEC IS UNSUPERVISED. WE NEED TO STOP THE TRAINING WHEN DELTA LOSS DIMINISHED AFTER CERTAIN ITERATION**

# %%
from nltk.stem import WordNetLemmatizer
import nltk
lemma = WordNetLemmatizer()
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
lemmatized_data = []
for i in train['title']:
  ss = i.split()
  a = []
  for j in ss:
    a.append(lemma.lemmatize(j))
  lemmatized_data.append(' '.join(a))

# %%
lemmatized_data
# Out:
# ['the best soundtrack ever to anything',
#  'amazing',
#  'excellent soundtrack',
#  'remember pull your jaw off the floor after hearing it',
#  'an absolute masterpiece',
#  'buyer beware',
#  'glorious story',
#  'a five star book',
#  'whisper of the wicked saint',
#  'the worst',
#  'great book',
#  'great read',
#  'oh please',
#  'awful beyond belief',
#  'dont try to fool u with fake review',
#  'a romantic zen baseball comedy',
#  'fashionable compression stocking',
#  'jobst ultrasheer thigh high',
#  'size recomended in the size chart are not real',
#  'men ultrasheer',
#  'delicious cookie mix',
#  'another abysmal digital copy',
#  'a fascinating insight into the life of modern japanese teen',
#  'i liked this album more then i thought i would',
#  'problem with charging smaller aaa',
#  'work but not a advertised',
#  'disappointed',
#  'oh dear',
#  'based on the review here i bought one and im glad i did',
#  'incorrect disc',
#  'happy with itbut',
#  'should be titled hollywood debacle',
#  'is this great tv you bet it is',
#  'nothing you dont already know',
#  'unfortunately it wasnt entertaining in the least bit',
#  'rochelle explains it all for you',
#  'more great playing',
#  'doesnt work on a mac',
#  'very frustrating',
#  'mind numbing',
#  'cannot recommend',
#  'alaska sourdough',
#  'old and good',
#  'autumn',
#  'fast mp3 download of music waxed decade ago',
#  'maybe i got a bad one',
#  'sylvania 6620ldg 20 flat panel lcd tv with built in dvd player',
#  'terrible do not buy this',
#  'beware',
#  'kitchen tv',
#  'nice for the money',
#  'disappointed romanian',
#  'great travel guide to europe',
#  'not the best',
#  'good but received defective book',
#  'from the label',
#  'either 1 or 5 star depends on how you look at it',
#  'hunting the hard way',
#  'disappointing',
#  'homer or moses',
#  'very poor quality',
#  'scraped across the whole top',
#  'unknown africa',
#  'didnt live up to expectation',
#  'profound then truly horrible now',
#  'definitely enjoyed',
#  'even mommy ha fun with this one',
#  'great combination of creativity and adventure',
#  'rapunzel',
#  'not what i expected',
#  'barbie rapunzel cry child',
#  'barbie a rapunzel a creative adventure',
#  'use your imagination',
#  'not so good ok for a rental',
#  'not o x but mac classic',
#  'bad deal',
#  'smell divine',
#  'very disappointed',
#  'creepy',
#  'audio option non existent',
#  'sooo jammin too trill',
#  'dirty south',
#  'good book',
#  'voice from the farm',
#  'little one maid of israel',
#  'it drew air',
#  'comfywarm but run big',
#  'buyer beware',
#  'ariel litte mermaid with pearl kit',
#  'no instruction included do not trust seller',
#  'why is soulwax ignored by critic consumer alike',
#  'omg soulwax owns',
#  'slow dull classical 1980s style movie',
#  'thank you for releasing it',
#  'very not worth your time',
#  'very fun and educational',
#  'ludicrous and silly',
#  'artistry',
#  'caution',
#  'textbook',
#  'a great book for historical romance lover',
#  'yes',
#  'not the best in the series',
#  'addonics portable cd drive i am disappointed in it performance',
#  'too uncomfortable and too big',
#  'very authentic',
#  'not the best',
#  'doesnt fit',
#  'you need a good memory',
#  'kelly club pet parade at hit my daughter love it',
#  'load of fun',
#  'easy and fun for 34yr old',
#  'hour of fun for my 4 and 6 year old',
#  'slip on 2 12 in heel shoe',
#  'ddr is cooool',
#  'amazing',
#  'i got fooled',
#  'i got fooled',
#  'more than letter',
#  'worth the wait',
#  'letter from home',
#  'no good',
#  'este libro contiene todo',
#  'oh',
#  'delicious and addictive',
#  'oh where oh where have my oh gone',
#  'one of a kind book for timber frame building',
#  'no technical information',
#  'hanford mill museum',
#  'you will not be able to buils a timber frame house',
#  'outstanding guidebook for building your own timberframe home',
#  'excellent book very poor ebook editing',
#  'a very good howto manual',
#  'poor instruction but once you figure it out kinda cool',
#  'great graphic',
#  'dont run out to get outrun unless your from 1985',
#  'my henry',
#  'henry ha come home',
#  'charisma',
#  'i found it henry dog',
#  'a contemporary fairytale sure to delight',
#  'not pattern but detailed sketch',
#  'great gift',
#  'product didnt match the picturedescription',
#  'good for a laugh',
#  'a bad a production a possible',
#  'not professional quality',
#  'three to four star depending',
#  'good song bad cover',
#  'new wave 80',
#  'dont be fooled',
#  'buyer beware',
#  'sony basic hi8 handycam rock',
#  'beware',
#  '80 high tech with rock emotion',
#  'never get going',
#  'now the rest of the story',
#  'the baseball benchmark',
#  'perfect for the diehard baseball fan',
#  'uh oh he been using brand x',
#  'this wa an intriguing book that influenced my destiny',
#  'peek a fun',
#  'excellent product',
#  'great for twin',
#  'theyre block keep that in mind',
#  'would have expected better',
#  'cute gift for a little baby',
#  'great block',
#  'awesume best block ever',
#  'keep his attention',
#  'great value',
#  'wonderful but not worth 80',
#  'worth the investment',
#  'waste off money',
#  'california exotics waterproof delight blue ballsy',
#  'small didnt work',
#  'make for fascinating reading',
#  'pretty nifty',
#  'yet another unsubstantiated case',
#  'molly myers',
#  'gardening lawn book',
#  'it a knock off',
#  'just a few',
#  'it wa ok but i wont watch it again',
#  'loved it p stephen colletti is so hot',
#  'mask maker',
#  'mask maker',
#  'not the worst american bmovie',
#  'mask of familiarity',
#  'unmasked',
#  'a museum exhibit inside a book',
#  'great resource for chineseeastern medincine',
#  'why is this a good book',
#  'a book that is worth a second look',
#  'best game ever',
#  'guitar in absentia',
#  'stiff and smell like drying paint',
#  'review of pillow',
#  'dont bother',
#  'worthless and cheap',
#  'will not be purchasing another one of these',
#  'false advertisement',
#  'not like the old formula',
#  'havent found better yet',
#  'smoothing serum',
#  'the product i received this time is like fake one',
#  'if it aint broke dont fix it',
#  'review of artec textureline smoothing serum',
#  'love it',
#  'the best',
#  'great control racquet',
#  'do not buy a waste of money and time',
#  'bad skating technique',
#  'a complete waste',
#  '4 year old bored with this after 2 week',
#  'barbies boring ice show',
#  'what a waste of money barbie ha sunk to new low',
#  'it great',
#  'a good game to buy',
#  'great game',
#  'not really what i wanted',
#  'rare find',
#  'fire truck puzzle',
#  'dark horse a must have cd',
#  'dont buy from eforcity slow disingenuous',
#  'dont waste your money',
#  'doe not work',
#  'plug it in and it work',
#  'mystical thinkman',
#  'the most charming captivating work from lj smith',
#  'beautiful love story',
#  'the best yet',
#  'the best',
#  'soulmates',
#  'possibly the best out of this series',
#  'amazing',
#  'one of the best book ive ever read',
#  'daughter of darknessthe best',
#  'one of her best in the night world series',
#  '2 human and 3 vampire after a vampire slayer',
#  'im hooked and i want some more',
#  'lj smith ha so many correct detail',
#  'it wa great',
#  'disappointing',
#  'mirroring the reader',
#  'dont waste yout time',
#  'thick dry and packed full of somewhat useful information',
#  'kylie take a bite at subtlety',
#  'a rare wondeful treat',
#  'nifty',
#  'grandson enjoyed maybe 20 time',
#  'very annoying',
#  'extremely disappointed with this video',
#  'just soso',
#  'more than thomas not geared toward child a much',
#  'a long promo for the thomas center',
#  'poor dvd',
#  'my son find it annoying',
#  'feel like a commercial',
#  'make you not want to sleep at night',
#  '25k warranty isnt included in packaging or at apc site',
#  'great little surge protector',
#  'too small',
#  'a good product available in convenient range of size',
#  'tom atkinson review',
#  'cut smaller than usual',
#  'wrong item sent',
#  'too bad',
#  'docker do the job',
#  'false advertising',
#  'dont trust the image',
#  'so disappointed',
#  'fantastic book',
#  'disturbing',
#  'a taste of italy',
#  'perfect book for a long flight',
#  'delicious reading',
#  'wonderfully romantic book that sweep you to italy',
#  'i just wanted to cook for my husband on those dark and stary night',
#  'one of the best',
#  'cameriere',
#  'food porn and i mean that in the best possible way',
#  'chick lit for foodie',
#  'not very good',
#  'do not waste your timelousy',
#  'the food is sexier than the sex',
#  'back to basic',
#  'cash money and no limit are tha same thang',
#  'just a trashy a garbage music come',
#  'this album is garbagestraight bfi material',
#  'i feel ya ghenry187aolthis cd rock no limit cant',
#  'save your',
#  'please dont buy this cd',
#  'worst music everbut i love it',
#  'classic',
#  'no not 5 starz 6 starz',
#  'this is a one compared to juvenilez 400 degreez',
#  'the worst rap i ever heard',
#  'super hot',
#  'super wack',
#  'ghetto foolishness',
#  'please try another hot boy album',
#  'fun to listen to',
#  'did you like 400 degreez',
#  'this cd iz aight',
#  'tha one',
#  'short book explaining love and logic',
#  'book review',
#  'a novel a enjoyable a the restaurant antoines',
#  'an old friend',
#  'not a ride on',
#  'excellent very useful',
#  'wonderful a thorough reference guide',
#  'fantastic advanced course',
#  'simply excellent no comparision',
#  'complete reference yes',
#  'good place to start web development',
#  'keep me healthy and i am not allergic to this brand',
#  'thoughtful contemporary fiction',
#  'why some people complain',
#  'my daughter hate it',
#  'glider',
#  'bench',
#  'great glider',
#  'gauge in chair arm',
#  'very nice glider',
#  'fantastic glider bench',
#  'james moody take san diego beyond the border',
#  'seal iv',
#  'woburn forgotten tale untold story',
#  'too much on the mystical plate',
#  'god zoo',
#  'different',
#  'awesome',
#  'an interesting little essay',
#  'great actor well done film',
#  'great movie not so great dvd',
#  'an extreme emotional ride',
#  'grrrrr arrrrgh',
#  'i give it 5 star because it entombed',
#  'bye bye mom and dad',
#  'bass voice delight in jazz music',
#  'danelectro dj20c rocky road spin speaker mini effect pedal',
#  'fabulous',
#  'she ha done it again',
#  'wonderful',
#  'a change from the carpathian series',
#  'riveting',
#  'not her best',
#  'this one is missing that feehan spark',
#  'intriguing story',
#  'amazing',
#  'too boring',
#  'ick ack put it back',
#  'disappointed',
#  'not up to scratch',
#  'wonderful gothic',
#  'you have another winner congratulation',
#  'an old world change thats definitely wonderful',
#  'great reading',
#  'i really wish i hadnt wasted my time',
#  'couldnt finish it',
#  'poor support',
#  'very good',
#  'great for the money',
#  'low resolution and poor quality',
#  'better than some out there',
#  'fun toy',
#  'cruel and unusual',
#  'good deal and fast shipping',
#  '23 of a great book then blah',
#  'review',
#  'love scarpetta',
#  'a really bad book',
#  'formula type writing',
#  'just plain cruel will do',
#  'cruel and unusual',
#  'i guess it wa a mystery',
#  'inproper advertising',
#  'solid addition to the series',
#  'still loving scarpetta',
#  'great',
#  'another one done',
#  'cruel and unusual',
#  'muddled ending disapoints',
#  'spellbound',
#  'very nice book',
#  'too scattered too shallow',
#  'soooooooooooo not funny',
#  'totally unfunny',
#  'nasty people nasty film',
#  'zero star',
#  'dramedy',
#  'the not so funny people',
#  'what happend sandler',
#  'serious comedy',
#  'long somewhat dull and unfocused',
#  'which joke did you find funny',
#  'far better than it reputation and well worth a look',
#  'start out with promise but then go downhill',
#  'not so funny people',
#  'obviously not adam sandlers best',
#  'not what i expected',
#  'couldnt give it less than one staror i wouldve',
#  'absolutely nothing funny',
#  'worst movie ive ever seen',
#  'worst film ever',
#  'the l o n g e s t movie ever',
#  'profanity the movie or profanity and the degenerate',
#  'seth kept this movie from getting a zero star rating',
#  'stupid',
#  'sandlers worst',
#  'not good',
#  'gift',
#  'waste of time',
#  'depressing then becomes boring',
#  'please just run far far away from this film',
#  'the worst movie ever made',
#  'moron',
#  'not funny',
#  'pretty pathetic people',
#  'great movie movie is longer than 2hours',
#  'not entirely a comedy',
#  'winning cast movie fell short',
#  'actually no star for rating pf funny people movie',
#  'not funny people',
#  'very inspirational',
#  'sfars best',
#  'the rabbi cat is the cat meow',
#  'a wonderful funnysad book',
#  'good artwork too',
#  'delightful exotic world seen through a cat eye',
#  'selfserving message',
#  'not what it look like on the cover',
#  'the last dissenting witness',
#  'see my article jean hill the lady in red online',
#  'drivel',
#  'an ever expanding story followed by same ol same ol',
#  'uneducated nonsense',
#  'great sword for a great price',
#  'fraudnot a advertised',
#  'impossible to read',
#  'nice size',
#  'still havent received item',
#  'curve',
#  'good value',
#  'unsatisfying ending disappoints the reader',
#  'the best patricia cornwells book',
#  'kay scarpetti is losing it',
#  'if you cant say anything nice',
#  'great read',
#  'you have got to be kidding',
#  'my brain froze over',
#  'losing her edge',
#  'the devil in the detail',
#  'the pit a contrived potboiler avoid it',
#  'so far the worst book of one of my favorite author',
#  'very dissapointing',
#  'intelligently written a fast and suspenseful read',
#  'what a disappointment',
#  'just awful',
#  'a wildly implausible thriller',
#  'from potter field buried with no name',
#  'impressive delivery but plot lacking in believability',
#  'no one will edit this because im patricia cornwell',
#  'a let down',
#  'to contrived and therefore not plausible',
#  'stilted and hokey',
#  'terror in central park',
#  'patricia cornwell rock best mystery writer on record',
#  'rekindling love',
#  'worst english dub of a great tv series',
#  'a piece of crap',
#  'no theory what so ever',
#  'you sure can tell this wa written by an accountant',
#  'wrong item',
#  'worthless',
#  'there no other book like this one',
#  'dont bother',
#  'lincoln and his time',
#  'explains why economics and politics dont mix',
#  'a brilliant wellwritten economics primer',
#  'dont waste your money',
#  'more of a personal opinion than that of economics',
#  'not what it claim to be',
#  'the best book on economics',
#  '35 starsa useful supplementary text for lower division microeconomic principle course only',
#  'title is a scam',
#  'no help',
#  'polemic and outdated',
#  'too simplistic',
#  'this aint no economics book',
#  'no lesson learned',
#  'best book on economics for the general reader',
#  'if you dont have this get it',
#  'read the angry antihazlitt review for a real indication',
#  'give this book to a your child',
#  'economics in one lesson',
#  'never more needed than today',
#  'economics even you will understand',
#  'simply brilliant',
#  'one lesson that everyone need to learn',
#  'textbook',
#  'our senator and rep should read and heed',
#  'great book',
#  'painful',
#  'unsatisfactory and very outdated',
#  'dont be fooled by the title of this book',
#  'hypocritical biased outdated and misleading',
#  'capitalism straight in small unpalatable dos',
#  'rightlibertarian view presented a fact',
#  'astounding',
#  'how to fail economics 101',
#  'read this if youre stupid and wish to be fanatically stupid',
#  'back to basic',
#  'a great alternative perspective',
#  'sanity in economics',
#  'fine summary',
#  'a good libertarian primer',
#  'important',
#  'economics',
#  'frighteningly prophetic',
#  'great book',
#  'great summary of some very difficult economic principle',
#  'oversimplified diatribe',
#  'more politics less economincs',
#  'this book title is misleading',
#  'seriously flawed',
#  'not a primer way too political',
#  'straight to the trash can',
#  'pretty cool',
#  'allison rock',
#  'kid love it',
#  'great for kid',
#  'chocolate delicious by body hottie',
#  'a stellar kid tape',
#  'too much kidpop music for a dark animated movie',
#  'tmnt soundtrack',
#  'egbert is such a wonderful name',
#  'sweet musing for loss and love',
#  'the art of chinese medical science',
#  'what more do i need',
#  'a great american sister book',
#  'not quite what i wa expecting',
#  'agressive wild experimental honnest poetry',
#  'nineteen folktale of south and central america',
#  'this book is incomprehensible',
#  'it wasnt very good',
#  'very boring',
#  'on order',
#  'long torso but great product',
#  'love this item',
#  'had some problem at first but now i love it',
#  'good choice for getting a vintage look',
#  'squeem work well',
#  'too small no return',
#  'wow',
#  'great',
#  'wasnt what i expected',
#  'great',
#  'a good smoother',
#  'work well',
#  'squeem cincher',
#  'not really worth it',
#  'great product great seller',
#  'painful experience',
#  'great product',
#  'poor fit',
#  'not recommended',
#  'gave me a waist but just pushed my fat around',
#  'advertized a new but arrives worn out',
#  'great result with some side effect',
#  'perfect for getting rid of pesky love handle',
#  'upset',
#  'falling apart',
#  'ahi',
#  'incrediby difficult to put on',
#  'squeem',
#  'a bit uncomfortable',
#  'this is the one',
#  'really love it',
#  'wow',
#  'not the shape i wa going for',
#  'bone',
#  'magic',
#  'wrong item shipped',
#  'sizing is ridiculous',
#  'so what is the sizing',
#  'cause sweat that make it unwearable',
#  'best money i ever spent on shape wear',
#  'work great',
#  'great at firstnot so good over time',
#  'recommend this',
#  'boning is not a plus',
#  'pas',
#  'love this',
#  'poor quality',
#  'squeem perfect waist firm compression',
#  'not the best shaper',
#  'it work but',
#  'squeem',
#  'product defective after 1 day of use',
#  'a great buy',
#  'nonono this is not for me',
#  'cant go wrong with this item',
#  'would be great but',
#  'work but uncomfortable',
#  'major let down',
#  'awsome',
#  'wasnt worth',
#  'great therapeutically a well a great for fashion',
#  'not so much',
#  'burn rubber on me',
#  'not worth the price',
#  'torture',
#  'squeem',
#  'im very impressed so far',
#  'not for everyone',
#  'squeem a combination of scream and squeeze',
#  'excelent product',
#  'hard to put on',
#  'why doe everybody rave when',
#  'uncomfortable',
#  'great idea poor design',
#  'best shapewear',
#  'waste of time for me',
#  'not ok',
#  'not worth the pain it cause',
#  'i love it',
#  'disappointed',
#  'itchy',
#  'i love it',
#  'wow ow and whats that smell',
#  'squeem is pretty good',
#  'snug fit',
#  'poor quality and lousy customer service',
#  'in the trash it go',
#  'very sturdy',
#  'worked for 5 day then broke',
#  'doe it job',
#  'squeem',
#  'so far so good',
#  'make me look like a i have a perfect hourglass figure',
#  'simple quick fix',
#  'a must have',
#  'the squeem waist cincher',
#  'wasnt that impressed',
#  'squeeeeeze into your clothes',
#  'love it',
#  'good product',
#  'waste of money',
#  'i got burned after few hour wearing it',
#  'doe not fit me',
#  'bulky feel gross not worth ordering',
#  'caused damage to my stomach muscle',
#  'great product',
#  'great product',
#  'love it',
#  'very good',
#  'it worked for me',
#  'not what i expected',
#  'too small',
#  'perfect',
#  'amazing',
#  'it amazing',
#  'awesome',
#  'fall apart',
#  'awesome',
#  'janes all the world aircraft 19967',
#  'marie antoinette what a doll',
#  'dont order them in white or any light color',
#  'this is disgusting',
#  'happy yet dissapointed',
#  'legend of dragoon soundtrack',
#  'i just wanted jimmy ponder too little guitar on this one',
#  'horrible',
#  'negative star avoid like flesh eating bacteria',
#  'worst movie ever',
#  'meh',
#  'religion and profit',
#  'ten gold banana for gorilla',
#  'the ending wa great',
#  'finally on cd',
#  'warning this is the worst book ever written',
#  'edge of danger',
#  'edge of danger',
#  'actually this book is not worth one star',
#  'not worth the reader time',
#  'disappointing and too simplistic',
#  'worst book ive ever read',
#  'formula writing',
#  'edge of danger by jack higgins',
#  'worst of theyearor maybe the decade',
#  'writing on autopilot',
#  'sophomoric at best',
#  'a waste of time',
#  'plenty of action',
#  'good story poor writing',
#  'do i have to give it 1star',
#  'disappointment on every page',
#  'i would rather watch paint dry',
#  'tired formula',
#  'this is not the jack higgins i know',
#  'completely predictable',
#  'extremely shallow',
#  'cartoon arabscottish villain',
#  'cant believe i read the whole thing',
#  'id rate it 0 star if i could have',
#  'a bad book poorly written',
#  'higgins disappoints',
#  'poorly written',
#  'a disappointment',
#  'horrible',
#  'not worth the effort',
#  'cant believe the publisher had nerve to issue this book',
#  'disappointing and thin',
#  'two hack',
#  'just skip it',
#  'worst live recording ive ever bought',
#  'a different collection of early stuff',
#  'great reference',
#  'excellent resource book',
#  'ha no value',
#  'really great baby book for your 4legged child',
#  'need upgrade',
#  'only window xp and earlier support',
#  'not very well written',
#  'hypatia',
#  'scarlett letter',
#  'boringridiculously long chapter',
#  'scarlet letter',
#  'the scarlett letter',
#  'a thorn in the side of literature',
#  'a moral novel with a mystery',
#  'excellent book',
#  'technical problem with cassette',
#  'mundane tedious just plain boring',
#  'oh god kill me now this book is bad',
#  'absolute waste of time',
#  'a tedious read',
#  'classic really',
#  'this book wa ok',
#  'ive read better',
#  'awakening',
#  'the scarlett letter',
#  'great condition almost exactly what i expected',
#  'gripping',
#  'good read but hard to navigate ebook',
#  'why 5 star because there no 6th',
#  'love it',
#  'remembered from high school eon ago',
#  'a classic',
#  'typo',
#  'decent book but definately not hanry david theraou',
#  'boring',
#  'hi',
#  'it great',
#  'the scarlet letter',
#  'review from one book at a time',
#  'amazingly good',
#  'interesting book',
#  'not my idea of a good read',
#  'good book to read if you were bored to death',
#  'a well written book',
#  'the scarlett letter is too verbose',
#  'bad book',
#  'duller than dirt',
#  'i must say',
#  'too hard to follow',
#  'historically accurate it may be but a boring read',
#  'wonderful classic',
#  'worth the effort',
#  'puritanical ostracism',
#  'wasted time',
#  'tragic',
#  'great',
#  'it nice',
#  'classic tale',
#  'a classic worth reading',
#  'do not read this book',
#  'my favorite classic',
#  'scarlet letter review',
#  'excellent romance in an excellent edition',
#  'the scarlet letter is a really good piece of literature',
#  'terrible book do not read it',
#  'meaningless drivel',
#  'worst book ever',
#  'who chooses classic',
#  'hallelujah is what i said when i finished this book',
#  'a must read',
#  'teacher this is not his best novel',
#  'very good and very unlike the movie',
#  'not kindle ready',
#  'good',
#  'boring very',
#  'boring',
#  'really hard to follow',
#  'a fascinating look into another time more',
#  'one word outdated',
#  'i wa fored to read it too',
#  'a tragedy',
#  'too had to read',
#  'simply the worse book ever',
#  'no active table of content',
#  'should not be a requirement in high school',
#  'it wa like a bad dream but i couldnt wake up',
#  'landscape book',
#  'the simple concept of sin taboo',
#  'excellent gift',
#  'great classic for the price',
#  'missing custom house',
#  'incredibly engrossing',
#  'characterization in the scarlet letter',
#  'the illiteracy of our generation',
#  'the scarlet letter ebook',
#  'i just dont get it',
#  'favorite classic',
#  'childish novel',
#  'jeff the scorned',
#  'ugh',
#  'this book wa dumb',
#  'avg rating too high',
#  'received a different book',
#  'oh my',
#  'far too little crime and fist fight',
#  'get to the point already',
#  'slow moving predictable story',
#  'good book if you look into it',
#  'greatread me read me read me',
#  'horrific forced reading',
#  'i read to page of this novel and i had to stop',
#  'i dont get it',
#  'i hate this book',
#  'it a if i were reading the book itself',
#  'way too boring for me',
#  'great plot horrible writing',
#  'get it away',
#  'overrated pretentious trash',
#  'the scarlet letter',
#  'a classic novel with a contemporary message',
#  'each read is like peeling layer of a rose',
#  'a better read a an adult not a great choice for teenager',
#  'dont pay for this on the kindle',
#  'strong woman',
#  'slow overwritten drama',
#  'great story bad writing',
#  'wonderful wonderful',
#  'awful',
#  'so boring',
#  'the okay book',
#  'i hate this book',
#  'dont read this book',
#  'if your looking to fall asleep than this is perfect 4 you',
#  'slowly falling asleep',
#  'one of the worst book ive ever read',
#  'i only gave it a star because i had to',
#  'paralyzing fear',
#  'a sin to humanity',
#  'forced to read the most horrible book ever',
#  'this book is a wast of good paper',
#  'scarlet letter',
#  'looooooooooooooooong',
#  'unable to review',
#  'painful',
#  'incredibly confusing have a dictionary on hand',
#  'save yourself',
#  'ick',
#  'confusing but good',
#  'sad',
#  'the next best thing to a sleeping pill',
#  'great',
#  'beautifully done',
#  'not what it is made out to be',
#  'hate this new format',
#  'wonderful',
#  'need a dictionary',
#  'an excellent portait of puritan new england',
#  'leave this one to the bibliophile',
#  'yes i wa another victim who had to read this for school',
#  'a book value',
#  'good read',
#  'not interesting at all',
#  'this book is incredibly boring',
#  'both forward and backward in it idea',
#  'i am going to bring hawthorne back from the grave to hit him',
#  'not worth reading',
#  'power to woman',
#  'it wa very slow',
#  'it wasnt good',
#  'ugh',
#  'a classicbut one of the worst book ever',
#  'how can sex and sin be so boring',
#  'unfinishable',
#  'american classic my',
#  'hawthorne masterpiece',
#  'useful for ap lit',
#  'timeless classic',
#  'one of the greatest book ever written',
#  'doe not have true plumeria scent',
#  'just a described',
#  'the ultimate for woman',
#  'boring',
#  'dual language selection from don quixote',
#  'best one in tomato trilogy',
#  'pretty fricken sweet',
#  'ft rule',
#  '100 time better than the first',
#  'too stupid',
#  'deception',
#  'warning you are not downloading little steven',
#  'warming dish sooooo helpful',
#  'not what we expected',
#  'not user friendly',
#  'not worth it',
#  'great warming dish',
#  'not user freindly',
#  'disappointed',
#  'not user friendly nothing that say it bpafree',
#  'sassy baby warming dish v gerber bowl',
#  'just what i wa looking for',
#  'musthave for childrens library',
#  'very informative',
#  '',
#  '1996 edition of book is outdated',
#  'disappointing',
#  'arrived broken',
#  'complicated',
#  'junk',
#  'entertaining but not for everybody',
#  'adam sandler lame a ever',
#  'one of the worst i have ever seen',
#  'nauseating',
#  'spare yourself',
#  'adam sandlers eight crazy night',
#  'a very disappointing movie',
#  '8 crazy night',
#  'clean it up',
#  '1 star since there no zero star available',
#  'eight crazy night',
#  'parent dont let your kid watch this movie',
#  'sandler is da bomb',
#  'the thrid in a string of flop for sandler',
#  'i want my money back',
#  'terrible movie',
#  'not a good hanukkah or christams movie',
#  'the worst movie ever made',
#  'ive seen this before',
#  'ugh',
#  'awesome',
#  'hilarious',
#  'adam sandler is awesome',
#  'crazy about 8 crazy night',
#  'childrens humor not suitable for child',
#  'nightmare before hannukah',
#  'okay there is a movie worse than stargate',
#  'worse movie ive seen in age',
#  'to be honest',
#  'suck',
#  'return to forever prototype',
#  'inappropriate for young child',
#  'dvd feature',
#  'my little thomas fan love this dvd',
#  'yo ho ho',
#  'illegible',
#  'the only boot my husband will wear',
#  'why so expensive',
#  'spun out',
#  'the road to love is full of danger sign',
#  'who else would have three beautiful woman after him',
#  'presley worst film',
#  'the music better than the movie',
#  'not a good spin for presley',
#  'spinout',
#  'piece of junk',
#  'work and is easy to use',
#  'great buy',
#  'great desk',
#  'good quality for price',
#  'great desk and a great buy thanks amazon',
#  'love kidkraft',
#  'great value for less money',
#  'very nice',
#  'very satisfied',
#  'great value for good quality product',
#  'if it good enough for popeye',
#  'a must have for all aspect of love devotee',
#  'cheap and dangerous',
#  'skip it buy the full sized version',
#  'slow',
#  'multilevel marketing meet education',
#  'wellresearched easy to read practical',
#  'pop psychology at it worse',
#  'get off the dead horse of old school education',
#  'easy read for brain information',
#  'fuzzy around the edge',
#  'brain based learning the new paradigm of teaching',
#  'brain based learning',
#  'pop psychology at it worst',
#  'science',
#  'an essential book for movie lover everywhere',
#  ...]

# %%
# !pip uninstall gensim numpy -y
# !pip install gensim
# Out:
# Found existing installation: gensim 4.3.3
# Uninstalling gensim-4.3.3:
#   Successfully uninstalled gensim-4.3.3
# Found existing installation: numpy 2.3.0
# Uninstalling numpy-2.3.0:
#   Successfully uninstalled numpy-2.3.0
# Collecting gensim
#   Using cached gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim) (7.1.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Using cached gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# Installing collected packages: numpy, gensim
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed gensim-4.3.3 numpy-1.26.4

# %%
pip install numpy==1.26.3
# Out:
# Collecting numpy==1.26.3
#   Downloading numpy-1.26.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 3.1 MB/s eta 0:00:00
# Downloading numpy-1.26.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 99.5 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.0 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.3 which is incompatible.
# Successfully installed numpy-1.26.3

# %% [markdown]
# Gensim is giving error in import in google colab but on local runtime it is running fine

# %%
import gensim.downloader as api
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-bfa495c1e338> in <cell line: 0>()
# ----> 1 import gensim.downloader as api
#
# /usr/local/lib/python3.11/dist-packages/gensim/__init__.py in <module>
#       9 import logging
#      10
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      12
#      13
#
# /usr/local/lib/python3.11/dist-packages/gensim/corpora/__init__.py in <module>
#       4
#       5 # bring corpus classes directly into package namespace, to save some typing
# ----> 6 from .indexedcorpus import IndexedCorpus  # noqa:F401 must appear before the other classes
#       7
#       8 from .mmcorpus import MmCorpus  # noqa:F401
#
# /usr/local/lib/python3.11/dist-packages/gensim/corpora/indexedcorpus.py in <module>
#      12 import numpy
#      13
# ---> 14 from gensim import interfaces, utils
#      15
#      16 logger = logging.getLogger(__name__)
#
# /usr/local/lib/python3.11/dist-packages/gensim/interfaces.py in <module>
#      17 import logging
#      18
# ---> 19 from gensim import utils, matutils
#      20
#      21
#
# /usr/local/lib/python3.11/dist-packages/gensim/matutils.py in <module>
#    1032 try:
#    1033     # try to load fast, cythonized code if possible
# -> 1034     from gensim._matutils import logsumexp, mean_absolute_difference, dirichlet_expectation
#    1035
#    1036 except ImportError:
#
# /usr/local/lib/python3.11/dist-packages/gensim/_matutils.pyx in init gensim._matutils()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
from gensim.models import Word2Vec
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-384f1c26d32d> in <cell line: 0>()
# ----> 1 from gensim.models import Word2Vec
#
# /usr/local/lib/python3.11/dist-packages/gensim/__init__.py in <module>
#       9 import logging
#      10
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      12
#      13
#
# /usr/local/lib/python3.11/dist-packages/gensim/corpora/__init__.py in <module>
#       4
#       5 # bring corpus classes directly into package namespace, to save some typing
# ----> 6 from .indexedcorpus import IndexedCorpus  # noqa:F401 must appear before the other classes
#       7
#       8 from .mmcorpus import MmCorpus  # noqa:F401
#
# /usr/local/lib/python3.11/dist-packages/gensim/corpora/indexedcorpus.py in <module>
#      12 import numpy
#      13
# ---> 14 from gensim import interfaces, utils
#      15
#      16 logger = logging.getLogger(__name__)
#
# /usr/local/lib/python3.11/dist-packages/gensim/interfaces.py in <module>
#      17 import logging
#      18
# ---> 19 from gensim import utils, matutils
#      20
#      21
#
# /usr/local/lib/python3.11/dist-packages/gensim/matutils.py in <module>
#    1032 try:
#    1033     # try to load fast, cythonized code if possible
# -> 1034     from gensim._matutils import logsumexp, mean_absolute_difference, dirichlet_expectation
#    1035
#    1036 except ImportError:
#
# /usr/local/lib/python3.11/dist-packages/gensim/_matutils.pyx in init gensim._matutils()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
def get_google_word2vec_embeddings(data):
    # Load the Google News Word2Vec model
    model = api.load("word2vec-google-news-300")

    tokenized_sentences = [sentence.split() for sentence in data]
    embeddings = []

    for sentence in tokenized_sentences:
        sentence_embeddings = []
        for word in sentence:
            if word in model:
                sentence_embeddings.append(model[word])
        if sentence_embeddings:
            embeddings.append(np.mean(sentence_embeddings, axis=0))
        else:
            embeddings.append(np.zeros(300))

    return np.array(embeddings)

train_x = get_google_word2vec_embeddings(lemmatized_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-92f74c1fa531> in <cell line: 0>()
#      18     return np.array(embeddings)
#      19
# ---> 20 train_x = get_google_word2vec_embeddings(lemmatized_data)
#
# <ipython-input-59-92f74c1fa531> in get_google_word2vec_embeddings(data)
#       1 def get_google_word2vec_embeddings(data):
#       2     # Load the Google News Word2Vec model
# ----> 3     model = api.load("word2vec-google-news-300")
#       4
#       5     tokenized_sentences = [sentence.split() for sentence in data]
#
# NameError: name 'api' is not defined

# %%
# @title
# def word2vec_trained_from_scratch(data):
#     tokenized_sentences = [sentence.split() for sentence in data]
#     model = Word2Vec(tokenized_sentences, vector_size=300, window=5, min_count=1, workers=4)

#     embeddings = []
#     for sentence in tokenized_sentences:
#         word_vectors = [model.wv[word] for word in sentence if word in model.wv]
#         if word_vectors:
#             sentence_embedding = np.mean(word_vectors, axis=0)
#         else:
#             sentence_embedding = np.zeros(model.vector_size)
#         embeddings.append(sentence_embedding)

#     return np.array(embeddings)

# train_x = torch.tensor(word2vec_trained_from_scratch(lemmatized_data),dtype=torch.float32)

# %%
train_x.shape
# Out:
# torch.Size([10000, 300])

# %%
# Dataset and DataLoader
class ReviewDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y
    def __len__(self):
        return len(self.X)
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

dataset = ReviewDataset(train_x,y_train)
dataloader = DataLoader(dataset, batch_size=16, shuffle=True)

# LSTM Model
class RNNClassifier(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNNClassifier, self).__init__()
        self.RNN = nn.RNN(input_size, hidden_size)
        self.rnn2 = nn.RNN(hidden_size, 100)

        self.h2o = nn.Linear(100, output_size)
        self.softmax = nn.LogSoftmax(dim=1)
    def forward(self, text):
        output, hidden = self.RNN(text)
        out, hid = self.rnn2(output)

        d= self.h2o(out)

        d = self.softmax(d)
        return d


vocab_size = 00
embed_dim = 300
hidden_dim = 32
num_classes = 16

model2 = RNNClassifier(embed_dim, hidden_dim, num_classes).to(device)
criterion = nn.CrossEntropyLoss().to(device)
optimizer = optim.Adam(model2.parameters(), lr=0.1)

# Training Loop
for epoch in range(10):
    for batch_X, batch_y in dataloader:
        optimizer.zero_grad()
        outputs = model2(batch_X.to(device))

        loss = criterion(outputs, torch.tensor(batch_y, dtype=torch.long).to(device))
        loss.backward()
        optimizer.step()
    print(f"Epoch {epoch+1}, Loss: {loss.item():.4f}")
# Out:
# /tmp/ipykernel_5876/1758969341.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   loss = criterion(outputs, torch.tensor(batch_y, dtype=torch.long))
# Epoch 1, Loss: 1.0299
# Epoch 2, Loss: 1.1594
# Epoch 3, Loss: 0.6785
# Epoch 4, Loss: 1.5967
# Epoch 5, Loss: 0.7624
# Epoch 6, Loss: 0.9336
# Epoch 7, Loss: 1.3046
# Epoch 8, Loss: 1.3732
# Epoch 9, Loss: 0.7739
# Epoch 10, Loss: 1.0269

# %%
# Dataset and DataLoader
class ReviewDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y
    def __len__(self):
        return len(self.X)
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

dataset = ReviewDataset(train_x,y_train)
dataloader = DataLoader(dataset, batch_size=16, shuffle=True)

# LSTM Model
class LSTMClassifier(nn.Module):
    def __init__(self,  embed_dim, hidden_dim, num_classes):
        super().__init__()
        self.embedding = nn.Embedding( embed_dim, 16)
        self.lstm = nn.LSTM(16, hidden_dim, batch_first=True, dropout=0.3)
        self.lstm2 = nn.LSTM(hidden_dim, hidden_dim, batch_first=True, dropout=0.3)
        self.ru1=nn.ReLU()
        self.fc = nn.Linear(hidden_dim, num_classes)
        self.ru = nn.ReLU()
    def forward(self, x):
        # print(x)
        # x = self.embedding(x)
        _, (hidden, _) = self.lstm(self.embedding(x))
        _, (hidden2, _) = self.lstm2(hidden)
        out = self.fc(self.ru1(hidden2[-1]))
        return self.ru(out)

vocab_size = 00
embed_dim = 300
hidden_dim = 32
num_classes = 16

model = LSTMClassifier( embed_dim, hidden_dim, num_classes).to(device)
criterion = nn.MSELoss().to(device)
optimizer = optim.Adam(model.parameters(), lr=0.01)

# Training Loop
for epoch in range(2):
    for batch_X, batch_y in dataloader:
        optimizer.zero_grad()
        outputs = model(torch.tensor(batch_X ,dtype=torch.long).to(device))

        loss = criterion(outputs, torch.tensor(batch_y, dtype=torch.float32).to(device))
        loss.backward()
        optimizer.step()
    print(f"Epoch {epoch+1}, Loss: {loss.item():.4f}")
# Out:
# /tmp/ipykernel_5876/1089609475.py:45: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   outputs = model(torch.tensor(batch_X ,dtype=torch.long))
# /tmp/ipykernel_5876/1089609475.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   loss = criterion(outputs, torch.tensor(batch_y, dtype=torch.float32))
# Epoch 1, Loss: 0.3317
# Epoch 2, Loss: 0.3330

# %%
lemmatized_test = []
for i in train['title']:
  ss = i.lower()
  ss = re.sub(r'[^\w\s]', '', ss)
  ss = ss.split()
  a = []
  for j in ss:
    a.append(lemma.lemmatize(j))
  lemmatized_test.append(' '.join(a))

# %%
test_x = torch.tensor(get_google_word2vec_embeddings(lemmatized_test), dtype=torch.float32)

# %%
y_test =torch.tensor(np.where(y_test == 1, 0,1))

# %%
dataset = ReviewDataset(test_x, y_test)
data = DataLoader(dataset, batch_size=16)

# %%
lstm_p = []

with torch.no_grad():
    for batch_X, batch_y in data:
        output = model(torch.tensor(batch_X,dtype=torch.long).to(device))

        lstm_p.append(output.squeeze(0))
# Out:
# /tmp/ipykernel_5876/3660709408.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   output = model(torch.tensor(batch_X,dtype=torch.long))

# %%
ss = 0
for i in range(625):
    for j in range(16):
        s = 1 if lstm_p[i][j] >0.4 else 0
        if (s == y_test[i*16+j]):
            ss += 1

# %%
print(f"Accuracy of LSTM is {ss/y_test.shape[0]}")
# Out:
# Accuracy of LSTM is 0.4903

# %%
rnn_p = []

with torch.no_grad():
    for batch_X, batch_y in data:
        output = model(torch.tensor(batch_X,dtype=torch.long).to(device))

        rnn_p.append(output.squeeze(0))

ss = 0
for i in range(625):
    for j in range(16):
        s = 1 if rnn_p[i][j] >0.4 else 0
        if (s == y_test[i*16+j]):
            ss += 1

print(f"Accuracy of RNN is {ss/y_test.shape[0]}")
# Out:
# /tmp/ipykernel_5876/198522299.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   output = model(torch.tensor(batch_X,dtype=torch.long))
# Accuracy of RNN is 0.4903
